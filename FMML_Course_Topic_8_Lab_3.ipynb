# %% [markdown]
# <a href="https://colab.research.google.com/github/hemanthkumar387/FMML_COURSE_ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-06-06 07:13:56--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   206MB/s    in 0.3s
#
# 2023-06-06 07:14:00 (206 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 388    1711.05136v4  Neuromorphic hardware tends to pose limits on ...    cs
# 37830   0706.3434v2  In this paper, we consider the problem of part...  stat
# 21576   1103.4789v3  We present the discrete infinite logistic norm...  stat
# 716    1602.01729v1  In hyperspectral images, some spectral bands s...  stat
# 7370   1712.01473v1  We consider deep linear networks with arbitrar...    cs
# ...             ...                                                ...   ...
# 10597  1505.01462v1  Data in the form of pairwise comparisons arise...    cs
# 7834   1803.07276v1  The rapid development of deep learning methods...  stat
# 9608    0912.2492v1  Many successful applications of computer visio...  stat
# 8678   1711.08589v1  Despite their widespread adoption, Product Qua...    cs
# 37903   1106.1674v1  Stochastic Kronecker graphs supply a parsimoni...  stat
#
#                                                    title  year  \
# 388    Deep Rewiring: Training very sparse deep networks  2017
# 37830  Separating populations with wide data: A spect...  2007
# 21576  The Discrete Infinite Logistic Normal Distribu...  2011
# 716    Correntropy Maximization via ADMM - Applicatio...  2016
# 7370   Deep linear neural networks with arbitrary los...  2017
# ...                                                  ...   ...
# 10597  Estimation from Pairwise Comparisons: Sharp Mi...  2015
# 7834   Fair Deep Learning Prediction for Healthcare A...  2018
# 9608         Learning an Interactive Segmentation System  2009
# 8678                  In Defense of Product Quantization  2017
# 37903  Moment based estimation of stochastic Kronecke...  2011
#
#                                                 keywords
# 388    [neuromorphic, connectivity, implementations, ...
# 37830  [partitioning, distributions, interested, indi...
# 21576  [distribution, nonparametric, membership, gene...
# 716    [hyperspectral, acquisition, atmospheric, requ...
# 7370   [arbitrary, differentiable, elementary, follow...
# ...                                                  ...
# 10597  [comparisons, including, preference, elicitati...
# 7834   [development, permitted, structured, applicati...
# 9608   [successful, applications, manipulation, inter...
# 8678   [widespread, quantization, techniques, techniq...
# 37903  [stochastic, kronecker, parsimonious, distribu...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 388      [neuromorphic, connectivity, implementations, ...
# 37830    [partitioning, distributions, interested, indi...
# 21576    [distribution, nonparametric, membership, gene...
# 716      [hyperspectral, acquisition, atmospheric, requ...
# 7370     [arbitrary, differentiable, elementary, follow...
#                                ...
# 34215    [literature, paraphrases, rewritings, citation...
# 1268     [improving, convolutional, determining, alignm...
# 10037    [developing, simulation, practical, experiment...
# 9794     [coreference, resolving, collections, automate...
# 22116    [observations, dimensional, dimensional, estim...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8785 words.
# Out of those 4546 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="fad04256-19fa-499d-9ba0-5f71f56aa0e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fad04256-19fa-499d-9ba0-5f71f56aa0e5")) {                    Plotly.newPlot(                        "fad04256-19fa-499d-9ba0-5f71f56aa0e5",                        [{"x":["configurations","connections","connected","constraints","recurrent","demonstrate","stochastic","theoretical","algorithm","supervised","feedforward","implementations","automatically","neuromorphic","connectivity","efficiently","posterior","performance","benchmark","foundation","according","interested","partitioning","population","individual","populations","distributions","application","motivated","divergence","individuals","partition","technique","correctly","clustering","separating","approximately","distribution","representation","nonparametric","hierarchical","generalization","membership","variables","variational","distributed","properties","correlation","inference","approximate","correlated","dirichlet","applications","structure","comparing","statistical","collection","normalized","empirical","alternating","optimization","promoting","demonstrating","requiring","synthetic","abundances","negativity","acquisition","scenarios","considers","robustness","criterion","hyperspectral","maximization","different","algorithms","atmospheric","experiments","direction","constrained","correntropy","corresponding","techniques","multipliers","arbitrary","elementary","differentiable","following","standalone","iteratively","guarantees","perplexity","comparison","guarantee","reductions","semantics","programming","introduce","significant","interpolation","guaranteed","linearized","corruption","transform","theoretically","deformation","initialize","convergence","experimental","computation","invariant","effectively","extensive","computational","decomposition","introduced","linguistic","evidenced","discussions","capabilities","relationships","transcripts","committee","discovers","evolution","uncovering","inferring","interaction","multivariate","influence","primarily","generative","arguments","augmentation","riemannian","challenging","alternative","exploiting","parameters","gradients","difficulties","marginalization","information","allocation","computing","demonstrated","unstructured","physicians","interpret","constructed","processing","prediction","readmission","predicting","statistic","unplanned","underlying","nonconvex","retrieving","complexity","iteration","formulate","efficient","significantly","percentage","empirically","simulations","favorably","dimensional","estimator","polyhedral","simulation","resulting","subspaces","deterministic","outperforms","conditions","unsupervised","generated","approximation","threshold","indicating","confident","uniformly","mislabeled","equivalent","estimation","similarly","impressively","uncorrupted","highlight","classification","estimating","classifier","regardless","probabilistic","unrestricted","solutions","consistent","memristors"],"y":[33,42,73,142,129,578,119,158,835,185,19,41,192,9,19,173,41,853,212,10,112,31,10,65,127,8,109,256,58,27,37,31,260,28,160,10,30,201,367,10,100,112,16,114,49,105,213,71,203,107,29,18,414,358,62,161,57,29,149,24,322,11,29,47,137,1,3,40,94,35,109,52,15,34,741,620,2,631,63,64,0,125,396,12,97,14,24,83,7,39,63,6,122,28,6,94,129,335,263,26,37,2,5,61,41,17,3,133,374,142,52,137,164,311,78,123,64,4,7,55,71,5,4,9,64,2,25,100,27,59,23,134,21,23,6,279,94,86,229,41,28,1,731,17,139,86,28,1,14,59,285,227,1,76,2,0,116,14,14,216,47,57,414,300,9,74,42,25,178,29,3,61,133,19,40,283,117,132,178,120,44,15,3,14,1,40,229,17,2,1,36,509,87,130,6,157,8,143,78,2],"type":"bar"},{"x":["configurations","connections","connected","constraints","recurrent","demonstrate", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4546,), (4546, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7933333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>OCRAPOSE</span> <span style=''>II</span> <span style=''>An</span> <span style=''>OCR</span> <span style=''>based</span> <span style=''>indoor</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>positioning</span> <span style=''>system</span> <span style=''>using</span> <span style=''>mobile</span> <span style=''>phone</span> <span style=''>images</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>OCR</span> <span style=''>(optical</span> <span style='background-color:rgba(0, 255, 0, 0.7352941176470589);'>character</span> <span style=''>recognition)</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.7179487179487178);'>localization</span> <span style=''>system</span> <span style=''>called</span> <span style=''>OCRAPOSE</span> <span style=''>II</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applicable</span> <span style=''>in</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style=''>indoor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scenarios</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>office</span> <span style='background-color:rgba(0, 255, 0, 0.75);'>buildings</span> <span style=''>parkings</span> <span style=''>airports</span> <span style=''>grocery</span> <span style=''>stores</span> <span style=''>etc</span> <span style=''>In</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scenarios</span> <span style='background-color:rgba(0, 255, 0, 0.8823529411764706);'>characters</span> <span style=''>(ie</span> <span style=''>texts</span> <span style=''>or</span> <span style=''>numbers)</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>as</span> <span style=''>suitable</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666665);'>distinctive</span> <span style='background-color:rgba(0, 255, 0, 0.6842105263157895);'>landmarks</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.7179487179487178);'>localization</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>system</span> <span style=''>takes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style=''>OCR</span> <span style=''>to</span> <span style=''>read</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.8823529411764706);'>characters</span> <span style=''>in</span> <span style=''>the</span> <span style=''>query</span> <span style=''>still</span> <span style=''>images</span> <span style=''>and</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>rough</span> <span style=''>location</span> <span style=''>estimate</span> <span style=''>using</span> <span style=''>a</span> <span style=''>floor</span> <span style=''>plan</span> <span style=''>Then</span> <span style=''>it</span> <span style=''>finds</span> <span style=''>depth</span> <span style=''>and</span> <span style=''>angle</span> <span style=''>of</span> <span style=''>view</span> <span style=''>of</span> <span style=''>the</span> <span style=''>query</span> <span style=''>using</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3254759746146872);'>information</span> <span style=''>provided</span> <span style=''>by</span> <span style=''>the</span> <span style=''>OCR</span> <span style=''>engine</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>refine</span> <span style=''>the</span> <span style=''>location</span> <span style=''>estimate</span> <span style=''>We</span> <span style=''>derive</span> <span style=''>novel</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>for</span> <span style=''>Coupled</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <br/><br/><span style=''>Sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>allow</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principled</span> <span style=''>and</span> <span style=''>scalable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>in</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style=''>(GP)</span> <span style=''>models</span> <span style=''>In</span> <span style=''>settings</span> <span style=''>where</span> <span style=''>several</span> <span style=''>GPs</span> <span style=''>are</span> <span style=''>part</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>model</span> <span style=''>theses</span> <span style=''>GPs</span> <span style=''>are</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posteriori</span> <span style=''>coupled</span> <span style=''>For</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>where</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>accuracy</span> <span style=''>is</span> <span style=''>the</span> <span style=''>quantity</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>this</span> <span style=''>coupling</span> <span style=''>is</span> <span style=''>not</span> <span style=''>crucial</span> <span style=''>Howewer</span> <span style=''>if</span> <span style=''>one</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interested</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>it</span> <span style=''>cannot</span> <span style=''>be</span> <span style=''>ignored</span> <span style=''>A</span> <span style=''>key</span> <span style=''>element</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>schemes</span> <span style=''>is</span> <span style=''>the</span> <span style=''>choice</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameterization</span> <span style=''>When</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>is</span> <span style=''>large</span> <span style=''>mean</span> <span style=''>field</span> <span style=''>(MF)</span> <span style=''>methods</span> <span style=''>provide</span> <span style=''>fast</span> <span style=''>and</span> <span style=''>accurate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=''>means</span> <span style=''>while</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>pos ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Mean</span> <span style=''>Field</span> <span style=''>Methods</span> <span style=''>for</span> <span style=''>a</span> <span style=''>Special</span> <span style=''>Class</span> <span style=''>of</span> <span style=''>Belief</span> <span style=''>Networks</span> <br/><br/><span style=''>The</span> <span style=''>chief</span> <span style=''>aim</span> <span style=''>of</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>to</span> <span style=''>propose</span> <span style=''>mean</span> <span style=''>field</span> <span style='background-color:rgba(255, 0, 0, 0.33834586466165417);'>approximations</span> <span style=''>for</span> <span style=''>a</span> <span style=''>broad</span> <span style=''>class</span> <span style=''>of</span> <span style=''>Belief</span> <span style=''>networks</span> <span style=''>of</span> <span style=''>which</span> <span style=''>sigmoid</span> <span style=''>and</span> <span style=''>noisy</span> <span style=''>or</span> <span style=''>networks</span> <span style=''>can</span> <span style=''>be</span> <span style=''>seen</span> <span style=''>as</span> <span style=''>special</span> <span style=''>cases</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.33834586466165417);'>approximations</span> <span style=''>are</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>powerful</span> <span style=''>mean</span> <span style=''>field</span> <span style=''>theory</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>suggested</span> <span style=''>by</span> <span style=''>Plefka</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>Saul</span> <span style=''>Jaakkola</span> <span style=''>and</span> <span style=''>Jordan</span> <span style=''>s</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>the</span> <span style=''>first</span> <span style=''>order</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>in</span> <span style=''>Plefkas</span> <span style=''>approach</span> <span style=''>via</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.6126482213438735);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>derivation</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>of</span> <span style=''>Plefkas</span> <span style=''>theory</span> <span style=''>to</span> <span style=''>belief</span> <span style=''>networks</span> <span style=''>is</span> <span style=''>not</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style='background-color:rgba(255, 0, 0, 0.31578947368421056);'>tractable</span> <span style=''>To</span> <span style=''>tackle</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.33834586466165417);'>approximations</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Taylor</span> <span style=''>series</span> <span style=''>Small</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>schemes</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attractive</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Efficiently</span> <span style=''>Bounding</span> <span style=''>Optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Solutions</span> <span style=''>after</span> <span style=''>Small</span> <span style=''>Data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Modification</span> <span style=''>in</span> <span style=''>Large</span> <span style=''>Scale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Empirical</span> <span style=''>Risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Minimization</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>large</span> <span style=''>scale</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>changing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environments</span> <span style=''>where</span> <span style=''>a</span> <span style=''>small</span> <span style=''>part</span> <span style=''>of</span> <span style=''>the</span> <span style=''>dataset</span> <span style=''>is</span> <span style=''>modified</span> <span style=''>and</span> <span style=''>the</span> <span style=''>effect</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modification</span> <span style=''>must</span> <span style=''>be</span> <span style=''>quickly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporated</span> <span style=''>into</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>When</span> <span style=''>the</span> <span style=''>entire</span> <span style=''>dataset</span> <span style=''>is</span> <span style=''>large</span> <span style=''>even</span> <span style=''>if</span> <span style=''>the</span> <span style=''>amount</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modification</span> <span style=''>is</span> <span style=''>fairly</span> <span style=''>small</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>cost</span> <span style=''>of</span> <span style=''>re</span> <span style=''>training</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>would</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prohibitively</span> <span style=''>large</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporating</span> <span style=''>such</span> <span style=''>a</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modification</span> <span style=''>effect</span> <span style=''>into</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>without</span> <span style=''>actually</span> <span style=''>re</span> <span style=''>training</span> <span style=''>it</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>provides</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style=''>unknown</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>with</span> <span style=''>the</span> <span style=''>cost</span> <span style=''>only</span> <span style='background-color:rgba(0, 255, 0, 0 ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10196779964221825)
# 	representation (0.13130590339892664)
# 	experimental (0.13381037567084078)
# 	architecture (0.08658318425760286)
# 	segmentation (0.07298747763864043)
# 	detection (0.1252236135957066)
# 	different (0.2651162790697674)
# 	information (0.26153846153846155)
# 	recognition (0.11735241502683363)
# 	convolutional (0.1334525939177102)
#
# Some Statistics words are:
# 	estimation (0.16957605985037408)
# 	theoretical (0.1456359102244389)
# 	algorithm (0.38952618453865334)
# 	stochastic (0.13615960099750624)
# 	statistical (0.15860349127182044)
# 	variables (0.15062344139650874)
# 	distribution (0.18453865336658354)
# 	inference (0.19251870324189527)
# 	dimensional (0.18753117206982545)
# 	regression (0.1740648379052369)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="208e8abb-3f2d-47fb-aa7f-3ab3b2cb006f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("208e8abb-3f2d-47fb-aa7f-3ab3b2cb006f")) {                    Plotly.newPlot(                        "208e8abb-3f2d-47fb-aa7f-3ab3b2cb006f",                        [{"x":["configurations","connections","connected","constraints","recurrent","demonstrate","stochastic","theoretical","algorithm","supervised","feedforward","implementations","automatically","neuromorphic","connectivity","efficiently","posterior","performance","benchmark","foundation","according","interested","partitioning","population","individual","populations","distributions","application","motivated","divergence","individuals","partition","technique","correctly","clustering","separating","approximately","distribution","representation","nonparametric","hierarchical","generalization","membership","variables","variational","distributed","properties","correlation","inference","approximate","correlated","dirichlet","applications","structure","comparing","statistical","collection","normalized","empirical","alternating","optimization","promoting","demonstrating","requiring","synthetic","abundances","negativity","acquisition","scenarios","considers","robustness","criterion","hyperspectral","maximization","different","algorithms","atmospheric","experiments","direction","constrained","correntropy","corresponding","techniques","multipliers","arbitrary","elementary","differentiable","following","standalone","iteratively","guarantees","perplexity","comparison","guarantee","reductions","semantics","programming","introduce","significant","interpolation","guaranteed","linearized","corruption","transform","theoretically","deformation","initialize","convergence","experimental","computation","invariant","effectively","extensive","computational","decomposition","introduced","linguistic","evidenced","discussions","capabilities","relationships","transcripts","committee","discovers","evolution","uncovering","inferring","interaction","multivariate","influence","primarily","generative","arguments","augmentation","riemannian","challenging","alternative","exploiting","parameters","gradients","difficulties","marginalization","information","allocation","computing","demonstrated","unstructured","physicians","interpret","constructed","processing","prediction","readmission","predicting","statistic","unplanned","underlying","nonconvex","retrieving","complexity","iteration","formulate","efficient","significantly","percentage","empirically","simulations","favorably","dimensional","estimator","polyhedral","simulation","resulting","subspaces","deterministic","outperforms","conditions","unsupervised","generated","approximation","threshold","indicating","confident","uniformly","mislabeled","equivalent","estimation","similarly","impressively","uncorrupted","highlight","classification","estimating","classifier","regardless","probabilistic","unrestricted","solutions","consistent","memristors","concludes","applicability","technology","essential","considered","discusses","generation","architecture","development","developments","describes","synchronization","themselves","distances","similarity","euclidean","approaches","recovering","likelihood","embedding","unweighted","scalability","localization","variation","furthermore","dimensionality","literature","transformations","comparisons","neighbors","coordinates","penalized","structural","configuration","illustrate","possibility","interface","extraction","incorporating","effective","physiological","evaluations","canonical","procedure","organized","contained","auxiliary","preserves","organization","dimensions","respective","evolutionary","chromatic","relationship","implementation","form ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	correntropy
# 	unplanned
# 	prominently
# 	multistep
# 	decouples
# 	manufacturability
# 	unmeasured
# 	independences
# 	crossings
# 	sufficiency
# 	straggler
# 	stragglers
# 	reversing
# 	additively
# 	appreciate
# 	conditionally
# 	undesired
# 	interfacing
# 	ergodicity
# 	predictivity
# Some words which never appear in Statistics papers:
# 	deformation
# 	memristors
# 	protecting
# 	authorities
# 	passengers
# 	superimposed
# 	digitized
# 	controllability
# 	illumination
# 	automaton
# 	supervisions
# 	countermeasures
# 	supervise
# 	dermoscopic
# 	morbidity
# 	instructions
# 	hydrocarbon
# 	alleviating
# 	coevolutionary
# 	prisoners

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.077301821762679e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7525
